# %%
import joblib

model = joblib.load("multinomial_model.pkl")
vectorizer = joblib.load("vectorizer.pkl")

# %%
sample1 = ["you have won 1 crore rupees lottery!!!"]
sample1_vec = vectorizer.transform(sample1)
print("Prediction:", model.predict(sample1_vec)[0])
# Out:
# Prediction: spam
